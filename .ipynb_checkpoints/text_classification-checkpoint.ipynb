# %%
# !pip install tensorflow_hub
# !pip install tf-keras
# Out:
# Requirement already satisfied: tensorflow_hub in c:\users\yashwanth\anaconda3\lib\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow_hub) (2.3.5)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow_hub) (7.34.1)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow_hub) (2.21.0)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in c:\users\yashwanth\anaconda3\lib\site-packages (from tf-keras>=2.14.1->tensorflow_hub) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.13.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.45.1)
# Requirement already satisfied: rich in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (14.2.0)
# Requirement already satisfied: namex in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.1.0)
# Requirement already satisfied: optree in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras>=2.14.1->tensorflow_hub) (0.1.2)
# Requirement already satisfied: tf-keras in c:\users\yashwanth\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: tensorflow<2.22,>=2.21 in c:\users\yashwanth\anaconda3\lib\site-packages (from tf-keras) (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow<2.22,>=2.21->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yashwanth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.22,>=2.21->tf-keras) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.22,>=2.21->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\yashwanth\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yashwanth\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow<2.22,>=2.21->tf-keras) (0.1.2)

# %%
# !pip uninstall tensorflow-hub -y
# !pip install tensorflow-hub==0.8.0
# Out:
# Found existing installation: tensorflow-hub 0.8.0
# Uninstalling tensorflow-hub-0.8.0:
#   Successfully uninstalled tensorflow-hub-0.8.0
# Collecting tensorflow-hub==0.8.0
#   Using cached tensorflow_hub-0.8.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow-hub==0.8.0) (2.3.5)
# Requirement already satisfied: six>=1.12.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow-hub==0.8.0) (1.17.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\yashwanth\anaconda3\lib\site-packages (from tensorflow-hub==0.8.0) (7.34.1)
# Using cached tensorflow_hub-0.8.0-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.8.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       4 import tensorflow as tf
#       5 from tensorflow import keras
# ----> 6 import tensorflow_hub as hub
#
# File ~\anaconda3\Lib\site-packages\tensorflow_hub\__init__.py:29
#      23 import tensorflow as tf
#      25 # pylint: disable=g-import-not-at-top
#      26 # Only do imports after check TensorFlow version so the useful
#      27 # error message is thrown instead of an obscure error of missing
#      28 # symbols at executing the imports.
# ---> 29 from tensorflow_hub.estimator import LatestModuleExporter
#      30 from tensorflow_hub.estimator import register_module_for_export
#      31 from tensorflow_hub.feature_column import image_embedding_column
#
# File ~\anaconda3\Lib\site-packages\tensorflow_hub\estimator.py:64
#      58       raise ValueError(
#      59           "There is already a module registered to be exported as %r"
#      60           % export_name)
#      61   tf_v1.add_to_collection(_EXPORT_MODULES_COLLECTION, (export_name, module))
# ---> 64 class LatestModuleExporter(tf_v1.estimator.Exporter):
#      65   """Regularly exports registered modules into timestamped directories.
#      66
#      67   DEPRECATION NOTE: This belongs to the hub.Module API and file format for TF1.
#    (...)     88   See `LatestModuleExporter.export()` for a direct use example.
#      89   """
#      91   def __init__(self, name, serving_input_fn, exports_to_keep=5):
#
# AttributeError: module 'tensorflow_hub.tf_v1' has no attribute 'estimator'

# %%
df = pd.read_csv("wine-reviews.csv", usecols = ['country', 'description', 'points', 'price', 'variety', 'winery'])

# %%
df.head()
